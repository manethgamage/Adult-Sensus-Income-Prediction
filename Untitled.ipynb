# %%
import zipfile
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with zipfile.ZipFile('adult (1).zip', 'r') as zip_ref:
    zip_ref.extractall('unzipped_folder')

column_names = [
    'age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status',
    'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss',
    'hours_per_week', 'native_country', 'income'
]

data_train = pd.read_csv('unzipped_folder/adult.data', names=column_names)
data_test = pd.read_csv('unzipped_folder/adult.test', skiprows=1, names=column_names)  

data = pd.concat([data_train, data_test], ignore_index=True)


data.to_csv('combined_adult.csv', index=False)
data.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education_num   48842 non-null  int64
#  5   marital_status  48842 non-null  object
#  6   occupation      48842 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital_gain    48842 non-null  int64
#  11  capital_loss    48842 non-null  int64
#  12  hours_per_week  48842 non-null  int64
#  13  native_country  48842 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.643585  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.710510  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data['income'].value_counts()
# Out:
# income
#  <=50K     24720
#  <=50K.    12435
#  >50K       7841
#  >50K.      3846
# Name: count, dtype: int64

# %%
data['income'] = data['income'].str.strip()
data['income'] = data['income'].replace({'<=50K.': '<=50K', '>50K.': '>50K'})

# %%
data['income'].value_counts()
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
data['sex'].value_counts()
# Out:
# sex
#  Male      32650
#  Female    16192
# Name: count, dtype: int64

# %%
data['workclass'].value_counts()
# Out:
# workclass
#  Private             33906
#  Self-emp-not-inc     3862
#  Local-gov            3136
#  ?                    2799
#  State-gov            1981
#  Self-emp-inc         1695
#  Federal-gov          1432
#  Without-pay            21
#  Never-worked           10
# Name: count, dtype: int64

# %%
data['native_country'].value_counts()
# Out:
# native_country
#  United-States                 43832
#  Mexico                          951
#  ?                               857
#  Philippines                     295
#  Germany                         206
#  Puerto-Rico                     184
#  Canada                          182
#  El-Salvador                     155
#  India                           151
#  Cuba                            138
#  England                         127
#  China                           122
#  South                           115
#  Jamaica                         106
#  Italy                           105
#  Dominican-Republic              103
#  Japan                            92
#  Guatemala                        88
#  Poland                           87
#  Vietnam                          86
#  Columbia                         85
#  Haiti                            75
#  Portugal                         67
#  Taiwan                           65
#  Iran                             59
# ...

# %%
data['occupation'].value_counts()
# Out:
# occupation
#  Prof-specialty       6172
#  Craft-repair         6112
#  Exec-managerial      6086
#  Adm-clerical         5611
#  Sales                5504
#  Other-service        4923
#  Machine-op-inspct    3022
#  ?                    2809
#  Transport-moving     2355
#  Handlers-cleaners    2072
#  Farming-fishing      1490
#  Tech-support         1446
#  Protective-serv       983
#  Priv-house-serv       242
#  Armed-Forces           15
# Name: count, dtype: int64

# %% [markdown]
# # Handeling null values

# %%
data.replace(r'^\s*\?\s*$', pd.NA, regex=True, inplace=True)

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         2799
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     857
# income               0
# dtype: int64

# %%
data.fillna(method = 'ffill', inplace = True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15172\757298848.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method = 'ffill', inplace = True)

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
data = data.drop(['education'],axis=1)
data
# Out:
#        age          workclass  fnlwgt  education_num       marital_status  \
# 0       39          State-gov   77516             13        Never-married
# 1       50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2       38            Private  215646              9             Divorced
# 3       53            Private  234721              7   Married-civ-spouse
# 4       28            Private  338409             13   Married-civ-spouse
# ...    ...                ...     ...            ...                  ...
# 48837   39            Private  215419             13             Divorced
# 48838   64            Private  321403              9              Widowed
# 48839   38            Private  374983             13   Married-civ-spouse
# 48840   44            Private   83891             13             Divorced
# 48841   35       Self-emp-inc  182148             13   Married-civ-spouse
#
#                occupation     relationship                 race      sex  \
# ...

# %%
data = data[data['hours_per_week'] <= 90]

# %%
filtered_data = data[(data['workclass'] == ' Never-worked') & (data['income'] == '>50K')]
filtered_data
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education_num, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hours_per_week, native_country, income]
# Index: []

# %%
filtered_data = data[(data['workclass'] == ' Without-pay') & (data['income'] == '>50K')]
filtered_data
# Out:
#        age     workclass  fnlwgt  education_num       marital_status  \
# 41464   64   Without-pay  209291              9   Married-civ-spouse
# 43208   50   Without-pay  123004              9   Married-civ-spouse
#
#                occupation relationship    race      sex  capital_gain  \
# 41464   Handlers-cleaners      Husband   White     Male             0
# 43208   Machine-op-inspct    Own-child   White   Female             0
#
#        capital_loss  hours_per_week  native_country income
# 41464             0              60   United-States   >50K
# 43208          1887              40   United-States   >50K

# %%
rows_to_drop = data[(data['workclass'] == ' Without-pay') & (data['income'] == '>50K')].index
data.drop(rows_to_drop, inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15172\3805006298.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(rows_to_drop, inplace=True)

# %%
filtered_data = data[(data['workclass'] == ' Without-pay') & (data['income'] == '>50K')]
filtered_data
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education_num, marital_status, occupation, relationship, race, sex, capital_gain, capital_loss, hours_per_week, native_country, income]
# Index: []

# %%
import matplotlib.pyplot as plt

above_50k = data[data['income'] == '>50K']['hours_per_week']
below_50k = data[data['income'] == '<=50K']['hours_per_week']

plt.figure(figsize=(10, 6))

plt.hist(above_50k, bins=20, color='red', alpha=0.7, label='Income > $50K')

plt.hist(below_50k, bins=20, color='black', alpha=0.7, label='Income <= $50K')

plt.axvline(above_50k.median(), color='red', linestyle='dashed', linewidth=1, label='Median (Income > $50K)')
plt.axvline(below_50k.median(), color='blue', linestyle='dashed', linewidth=1, label='Median (Income <= $50K)')

plt.xlabel('Hours per Week')
plt.ylabel('Frequency')
plt.title('Distribution of Working Hours per Week')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
occupation_income_counts = data.groupby(['occupation', 'income']).size().unstack()

occupation_total_counts = occupation_income_counts.sum(axis=1)

occupation_above_50k_counts = occupation_income_counts['>50K']

occupation_above_50k_percentage = (occupation_above_50k_counts / occupation_total_counts) * 100

occupation_income_counts['Percentage >50K'] = occupation_above_50k_percentage

occupation_income_counts
# Out:
# income              <=50K  >50K  Percentage >50K
# occupation
#  Adm-clerical        5131   801        13.503034
#  Armed-Forces          11     6        35.294118
#  Craft-repair        5081  1417        21.806710
#  Exec-managerial     3500  2934        45.601492
#  Farming-fishing     1358   177        11.530945
#  Handlers-cleaners   2071   149         6.711712
#  Machine-op-inspct   2832   392        12.158809
#  Other-service       4951   233         4.494599
#  Priv-house-serv      254     3         1.167315
#  Prof-specialty      3724  2807        42.979636
#  Protective-serv      716   307        30.009775
#  Sales               4302  1499        25.840372
#  Tech-support        1101   428        27.992152
#  Transport-moving    2000   484        19.484702

# %%
# # Threshold percentage for considering low percentage of individuals earning above 50K
# threshold_percentage = 15

# # Threshold for low working hours per week
# hours_threshold = 15

# # Get occupation classes with a percentage of individuals earning above 50K below the threshold
# low_income_percentage_classes = occupation_income_counts[occupation_income_counts['Percentage >50K'] < threshold_percentage].index

# # Get potential outliers based on low income percentage and low working hours
# potential_outliers = data[(data['occupation'].isin(low_income_percentage_classes)) & (data['hours_per_week'] < hours_threshold) & (data['income'] == '>50K')]
# potential_outliers.shape

# data = data.drop(potential_outliers.index)

# %%
data.shape
# Out:
# (48669, 14)

# %%
# # Threshold percentage for considering low percentage of individuals earning above 50K
# threshold_percentage = 40

# # Threshold for low working hours per week
# hours_threshold = 80

# # Get occupation classes with a percentage of individuals earning above 50K below the threshold
# low_income_percentage_classes = occupation_income_counts[occupation_income_counts['Percentage >50K'] > threshold_percentage].index

# # Get potential outliers based on low income percentage and low working hours
# potential_outliers = data[(data['occupation'].isin(low_income_percentage_classes)) & (data['hours_per_week'] > hours_threshold) & (data['income'] == '<=50K')]
# potential_outliers.shape

# # data = data.drop(potential_outliers.index)

# %% [markdown]
# # Feature Engineering

# %%
data['native_country'].value_counts()
# Out:
# native_country
#  United-States                 44450
#  Mexico                          966
#  Philippines                     297
#  Germany                         211
#  Puerto-Rico                     188
#  Canada                          185
#  El-Salvador                     161
#  India                           156
#  Cuba                            139
#  England                         129
#  China                           125
#  South                           114
#  Jamaica                         108
#  Italy                           106
#  Dominican-Republic              105
#  Japan                            92
#  Vietnam                          91
#  Guatemala                        90
#  Poland                           87
#  Columbia                         86
#  Haiti                            76
#  Portugal                         67
#  Taiwan                           65
#  Iran                             59
#  Greece                           50
# ...

# %%
def mark(x):
    if x in " United-States":
        return 'United-States'
    else:
        return 'Non-US'

# %%
data['native_country'] = data['native_country'].apply(mark)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15172\590392226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['native_country'] = data['native_country'].apply(mark)

# %%
data
# Out:
#        age          workclass  fnlwgt  education_num       marital_status  \
# 0       39          State-gov   77516             13        Never-married
# 1       50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2       38            Private  215646              9             Divorced
# 3       53            Private  234721              7   Married-civ-spouse
# 4       28            Private  338409             13   Married-civ-spouse
# ...    ...                ...     ...            ...                  ...
# 48837   39            Private  215419             13             Divorced
# 48838   64            Private  321403              9              Widowed
# 48839   38            Private  374983             13   Married-civ-spouse
# 48840   44            Private   83891             13             Divorced
# 48841   35       Self-emp-inc  182148             13   Married-civ-spouse
#
#                occupation     relationship                 race      sex  \
# ...

# %%
data['marital_status'].value_counts()
# Out:
# marital_status
#  Married-civ-spouse       22264
#  Never-married            16089
#  Divorced                  6610
#  Separated                 1528
#  Widowed                   1515
#  Married-spouse-absent      626
#  Married-AF-spouse           37
# Name: count, dtype: int64

# %%
marital_status_counts = data['marital_status'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(marital_status_counts, labels=marital_status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Marital Status')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# data['marital_status'] = data['marital_status'].replace([' Divorced',' Married-spouse-absent',' Never-married',' Separated',' Widowed'],'Single')
# data['marital_status'] = data['marital_status'].replace([' Married-AF-spouse',' Married-civ-spouse'],'Couple')
# data.head(10)

# %%
data['workclass'].value_counts()
# Out:
# workclass
#  Private             35939
#  Self-emp-not-inc     4033
#  Local-gov            3292
#  State-gov            2092
#  Self-emp-inc         1773
#  Federal-gov          1508
#  Without-pay            22
#  Never-worked           10
# Name: count, dtype: int64

# %%
def f(x):
    if x['workclass'] == ' Federal-gov' or x['workclass']== ' Local-gov' or x['workclass']==' State-gov': return 'govt'
    elif x['workclass'] == ' Private':return 'private'
    elif x['workclass'] == ' Self-emp-inc' or x['workclass'] == ' Self-emp-not-inc': return 'self_employed'
    else: return 'without_pay'
    
    
data['workclass']=data.apply(f, axis=1)

data.head(10)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15172\2245025078.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass']=data.apply(f, axis=1)
#    age      workclass  fnlwgt  education_num          marital_status  \
# 0   39           govt   77516             13           Never-married
# 1   50  self_employed   83311             13      Married-civ-spouse
# 2   38        private  215646              9                Divorced
# 3   53        private  234721              7      Married-civ-spouse
# 4   28        private  338409             13      Married-civ-spouse
# 5   37        private  284582             14      Married-civ-spouse
# 6   49        private  160187              5   Married-spouse-absent
# ...

# %%
x=data['capital_gain']
plt.hist(x,bins=None)
plt.show()

# %%
# data.loc[(data['capital_gain'] > 0),'capital_gain'] = 1
# data.loc[(data['capital_gain'] == 0 ,'capital_gain')]= 0
# data.loc[(data['capital_loss'] > 0),'capital_loss'] = 1
# data.loc[(data['capital_loss'] == 0 ,'capital_loss')]= 0

# %%
data
# Out:
#        age      workclass  fnlwgt  education_num       marital_status  \
# 0       39           govt   77516             13        Never-married
# 1       50  self_employed   83311             13   Married-civ-spouse
# 2       38        private  215646              9             Divorced
# 3       53        private  234721              7   Married-civ-spouse
# 4       28        private  338409             13   Married-civ-spouse
# ...    ...            ...     ...            ...                  ...
# 48837   39        private  215419             13             Divorced
# 48838   64        private  321403              9              Widowed
# 48839   38        private  374983             13   Married-civ-spouse
# 48840   44        private   83891             13             Divorced
# 48841   35  self_employed  182148             13   Married-civ-spouse
#
#                occupation     relationship                 race      sex  \
# ...

# %%
data['capital_loss'].value_counts()
# Out:
# capital_loss
# 0       46395
# 1902      303
# 1977      250
# 1887      232
# 1485       71
#         ...
# 1539        1
# 1870        1
# 1911        1
# 2465        1
# 1421        1
# Name: count, Length: 99, dtype: int64

# %%
# Assuming your DataFrame is named 'data'
filtered_data = data[(data['hours_per_week'] < 10) & (data['income'] == '>50K')]

# Print the filtered data
filtered_data.shape
# Out:
# (72, 14)

# %%
# Assuming your DataFrame is named 'data'
data.drop(data[(data['hours_per_week'] < 10) & (data['income'] == '>50K')].index, inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15172\2636912981.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(data[(data['hours_per_week'] < 10) & (data['income'] == '>50K')].index, inplace=True)

# %%
data = data.drop(['race'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['workclass'] = le.fit_transform(data['workclass'])
data['marital_status'] = le.fit_transform(data['marital_status'])
data['occupation'] = le.fit_transform(data['occupation'])
data['relationship'] = le.fit_transform(data['relationship'])
# data['race'] = le.fit_transform(data['race'])
data['sex'] = le.fit_transform(data['sex'])
data['native_country'] = le.fit_transform(data['native_country'])
data['income'] = le.fit_transform(data['income'])

data.head()
# Out:
#    age  workclass  fnlwgt  education_num  marital_status  occupation  \
# 0   39          0   77516             13               4           0
# 1   50          2   83311             13               2           3
# 2   38          1  215646              9               0           5
# 3   53          1  234721              7               2           5
# 4   28          1  338409             13               2           9
#
#    relationship  sex  capital_gain  capital_loss  hours_per_week  \
# 0             1    1          2174             0              40
# 1             0    1             0             0              13
# 2             1    1             0             0              40
# 3             0    1             0             0              40
# 4             5    0             0             0              40
#
#    native_country  income
# 0               1       0
# 1               1       0
# 2               1       0
# 3               1       0
# ...

# %%
X = data.drop(['income'],axis=1)
Y = data['income']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB
gb = GaussianNB()
rf = RandomForestClassifier()
gb.fit(X_train,Y_train)
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score 
y_pred = gb.predict(X_test)
y_preds = rf.predict(X_test)
print(accuracy_score(Y_test,y_pred)*100)
print(accuracy_score(Y_test,y_preds)*100)
# Out:
# 79.72222222222223
# 85.73045267489712

# %%
# from sklearn.metrics import precision_score, recall_score

# precision = precision_score(Y_test, y_pred)

# # Calculate recall
# recall = recall_score(Y_test, y_pred)

# # Print precision and recall
# print("Precision:", precision)
# print("Recall:", recall)

# %%
# from sklearn.metrics import f1_score, confusion_matrix

# # Assuming you have true labels (y_true) and predicted labels (y_pred)
# # Compute the F1 score
# f1 = f1_score(Y_test, y_pred)

# # Compute the confusion matrix
# cm = confusion_matrix(Y_test, y_pred)

# # Print the F1 score
# print("F1 Score:", f1)

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(cm)

# %%
importances = dict(zip(rf.feature_names_in_,rf.feature_importances_))
importances = {k: v for k , v in sorted(importances.items(), key = lambda x:x[1],reverse=True)}
importances
# Out:
# {'fnlwgt': 0.19551566678937388,
#  'age': 0.15753350557254173,
#  'education_num': 0.12242399065350866,
#  'capital_gain': 0.1178934224948424,
#  'relationship': 0.1067293113424679,
#  'hours_per_week': 0.08595410999257155,
#  'marital_status': 0.06719987781526784,
#  'occupation': 0.06531745124792236,
#  'capital_loss': 0.037069037155727166,
#  'workclass': 0.025153199170866763,
#  'sex': 0.010211103736461611,
#  'native_country': 0.008999324028447941}
